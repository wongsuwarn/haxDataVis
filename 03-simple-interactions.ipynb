# %% [markdown]
# One of the most distinguishing features of Altair is the way in which it enables interactive data visualisation. The Altair Chart method interactive() enables intuitive panning and zooming with the mouse.

# %%
alt.Chart(cas_sample_df).mark_point().encode(
    x='total_number_visits_all_time',
    y='total_net_gp_all_time'
).interactive()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(bkg_sample_df).mark_point().encode(
    x='visit_page_number',
    y='gross_booking_value_usd'
).interactive()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %%
alt.Chart(cas_sample_df).mark_point().encode(
    x='average_gbv_all_time',
    y='average_daily_rate_all_time'
).interactive()
# Out:
# <VegaLite 3 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
